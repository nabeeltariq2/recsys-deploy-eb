# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
meta_df = getDF('meta_Amazon_Instant_Video (1).json.gz')

# %%
meta_df.to_csv("meta.csv")

# %%
reviews_df = getDF('reviews_Amazon_Instant_Video_5 (2).json.gz')

# %%
reviews_df.to_csv("reviews.csv")

# %%
# Out:
#              asin                categories  price related
# 0      B000GFDAUG  [[Amazon Instant Video]]    NaN     NaN
# 1      B000GIOPK2  [[Amazon Instant Video]]    NaN     NaN
# 2      B000GIPKWY  [[Amazon Instant Video]]    NaN     NaN
# 3      B000GJUQ7M  [[Amazon Instant Video]]    NaN     NaN
# 4      B000GK0NBK  [[Amazon Instant Video]]    NaN     NaN
# 5      B000GK51HG  [[Amazon Instant Video]]    NaN     NaN
# 6      B000GK7DPY  [[Amazon Instant Video]]    NaN     NaN
# 7      B000GK6NFK  [[Amazon Instant Video]]    NaN     NaN
# 8      B000GOTJGG  [[Amazon Instant Video]]    NaN     NaN
# 9      B000GOV10S  [[Amazon Instant Video]]    NaN     NaN
# 10     B000GOW9B8  [[Amazon Instant Video]]    NaN     NaN
# 11     B000GP0T82  [[Amazon Instant Video]]    NaN     NaN
# 12     B000GOW7RE  [[Amazon Instant Video]]    NaN     NaN
# 13     B000GOYLNC  [[Amazon Instant Video]]    NaN     NaN
# 14     B000GP38JE  [[Amazon Instant Video]]    NaN     NaN
# ...
